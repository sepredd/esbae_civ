# %% [markdown]
# <font face="Calibri" size="2"> <i>eSBAE - Notebook Series - Part 3, version 0.4, March 2023. Andreas Vollrath, UN-Food and Agricultural Organization, Rome</i>
# </font>

# %% [markdown]
# ![title](images/header.png)
#
# # III - eSBAE Time-Series Extraction
# ### Extract various time-series data for large sets of points from Google Earth Engine
# -------
#
# This notebook takes you through the process of extracting time-series for a set of points using [Google's Earth Engine](https://earthengine.google.com/). The script is optimized to deal with thousands of points and will use parallelization to efficiently extract the information from the platform.
#
# **You will need**:
# - a valid Earth Engine account ([sign up here](https://code.earthengine.google.com/register))
# - an uploaded table of points (Feature Collection)
# - the table needs a unique point identifier (Point ID)
#
# **You should be aware, that:**
#
# - As a SEPAL user: this notebook does **not need huge resources**, as processing is done on the platform. A **m2 instance** is best suited.
# - The extraction can take up to days (>100000 points). If you are on SEPAL, make use of the **"keep instance running"** option within the user report dashboard. However, **do not forget** to shut down your machine once processing finished.
# - A logfile is created within your tmp-folder. Interruption of connectivity to the SEPAL server may lead to block the output of the Jupyter notebook. **This does not mean the processing stopped.** You can see in esbae_log_(time) if the processing is still on going.
# - You can restart the kernel and execute all cells, and extraction will **start where it stopped**. This is also valid, if your instance has been shut down before processing was completely finished.

# %% [markdown]
# ### 1 - Import libraries (*only execute this cell*)
#
# This cell will provide us with the functionality we need for running the subsequent cells of the notebook.

# %%
# initialize EE    
import ee
try:
    ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')
except:
    ee.Authenticate()
    ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')
    
from sampling_handler import TimeSeriesExtraction
# Out:
# /usr/local/share/jupyter/kernels/venv-eSBAE_notebooks/venv/lib/python3.8/site-packages/bfast/__init__.py:10: UserWarning: cupy is not available in this environment, GPU fonctionnalities won't be available
#   warn("cupy is not available in this environment, GPU fonctionnalities won't be available")

# %% [markdown]
# ### 2 - Basic Input Variables
#
# Here a so called class instance is initialized. The class instance needs some parameters to be set and is written into the *esbae* variable.

# %%
esbae = TimeSeriesExtraction(
     # your project name that you use fo all of the notebooks
    project_name  = 'sepredd',
    
    # your start and end date. 
    # NOTE that this should go further back to the past than the 
    # envisaged monitoing period for calibration purposes
    ts_start      = '2015-01-01',      # YYYY-MM-DD format
    ts_end        = '2023-01-01',        # YYYY-MM-DD format
    
    # satellite platform (for now only Landsat is supported)
    satellite     = 'Landsat',
    
    # at what resolution in metres you want to extract (shall conform with forest definition MMU)
    scale         = 70, # pixel size in metres
    
    # wether the TS will be extracted on a bounding box with diameter scale with original scale (e.g 30m for Landsat) of the underlying data (True), 
    # or if the underlying data is rescaled to the scale (False)
    # setting it to True might be more accurate, but tends to be slower
    bounds_reduce = False,
    
    # bands
    bands         =  [
        'green', 'red', 'nir', 'swir1', 'swir2',   # reflectance bands
        'ndfi', #'ndmi', 'ndvi',                    # indices
        'brightness', 'greenness', 'wetness'       # Tasseled Cap 
    ], 
    # This is in case you haven't run notebook 1 and 2, and want to directly start from here
    aoi = ee.FeatureCollection(ee.FeatureCollection('users/fao-dannunzio/grid_1km_CIV_sinus').geometry().convexHull(100))
    
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# INFO: Using existing project directory at /home/sepal-user/module_results/esbae/sepredd
# INFO: Using existent config file from project directory /home/sepal-user/module_results/esbae/sepredd

# %% [markdown]
# ### 3 - Landsat parameters
#
# Here you can select, which satellites you want to include from the Landsat mission.
# In addition you can select the BRDF correction and a filter for maximum cloud cover. Note that the bands parameter is already set in the initialization and will be taken from the class attribute.

# %%
# landsat related parameters
lsat_params = {
    'l9': True,
    'l8': True,
    'l7': True,
    'l5': True,
    'l4': True,
    'brdf': True,
    'bands': esbae.bands,
    'max_cc': 75    # percent
} 

# apply the basic configuration set in the cell above
esbae.lsat_params = lsat_params
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### 4 - Processing parameters
#
# Here you can refine the parallelization options. For efficient extraction, the time-series extraction is done on chunks of data, defined by squared grids of given sizes. The routine will check how many points are in each chunk. If this is below the max_points_per_chunk, it will go on and process those points. Otherwise it will try to process those points at a lower grid size level. Some optimized settings are given below, comment and uncomment as appropriate.

# %%
esbae.workers = 10                   # this defines how many parallel requests will be send to EarthEngine at a time
esbae.max_points_per_chunk = 100     # this defines the maximum amount of points as send per request to Earth Engine at a time

# this defines the chunk sizes (in degree) to create the requests
#esbae.grid_size_levels = [0.1, 0.075, 0.05]   # optimized for 1km systematic grid
esbae.grid_size_levels = [0.2, 0.15, 0.1]    # optimized for 2km systematic grid
#esbae.grid_size_levels = [0.4, 0.3, 0.2]     # optimized for 4km systematic grid
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### 5 - Set a custom grid
#
# This step is only necessary if you skipped notebook 2. You then need to define an Earth Engine feature collection as well as the unique point identifier. Uncomment the lines by removing the #

# %%
#esbae.sample_asset = 'users/username/my_already_existing_points'
#esbae.pid = 'my_unique_point_id'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
esbae.sample_asset = 'users/fao-dannunzio/grid_1km_CIV_sinus'
esbae.pid = 'point_id'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### 4 - Check for already processed data (optional)
#
# This is useful for large points sizes and when the connection to Sepal gets interrupted. Usually processing will continue, but it is not straightforward to track progress.
# You can instead restart the kernel, execute all cells and see if processing has been finished with the following line of code.

# %%
esbae.check_if_completed()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# INFO: Verifying the number of points for which the time-series have already been extracted...
# INFO: Time-series data has been extracted partially. 222968 points missing of a total of 325631

# %% [markdown]
# ### 5 - Run the time-series data extraction *(only execute this)*

# %%
esbae.get_time_series_data()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# INFO: Verifying parameter settings...
# INFO: The number of points exceeds 25000. Processing will be split into 14 subsets.
# INFO: ------------------------------------------------
# INFO: Processing subset 1/14
# INFO: ------------------------------------------------
# INFO: No time-series data has been extracted yet.
# INFO: Create AOI from points and upload as temporary EE asset inside tmp_esbae_231107_191832.
# INFO: Creating processing chunks of 0.2 degrees for parallel extraction.
# INFO: Preparing the parallel extraction over a total of 16 chunks. This may take a while...
# INFO: Starting the parallel extraction routine.
# INFO: Extracting 78 points for chunk nr 0 at resolution 0.2
# INFO: Extracting 79 points for chunk nr 3 at resolution 0.2
# INFO: Extracting 9 points for chunk nr 9 at resolution 0.2
# INFO: Extracting 46 points for chunk nr 7 at resolution 0.2
# INFO: Extracting 35 points for chunk nr 4 at resolution 0.2
# INFO: Extracting 94 points for chunk nr 8 at resolution 0.2
# INFO: Extracting 78 points for chunk nr 5 at resolution 0.2
# INFO: Extracting 4 points for chunk nr 1 at resolution 0.2
# INFO: Extracting 14 points for chunk nr 2 at resolution 0.2
# INFO: Extracting 15 points for chunk nr 6 at resolution 0.2
# INFO: 78 points for chunk nr 5 at resolution 0.2 extracted in:: 0:01:47.782186
# INFO: 15 points for chunk nr 6 at resolution 0.2 extracted in:: 0:01:47.006982
# INFO: Extracting 9 points for chunk nr 10 at resolution 0.2
# INFO: Extracting 27 points for chunk nr 11 at resolution 0.2
# INFO: 14 points for chunk nr 2 at resolution 0.2 extracted in:: 0:01:56.885077
# INFO: Extracting 1 points for chunk nr 12 at resolution 0.2
# INFO: 35 points for chunk nr 4 at resolution 0.2 extracted in:: 0:02:46.958086
# INFO: Extracting 1 points for chunk nr 13 at resolution 0.2
# INFO: 9 points for chunk nr 9 at resolution 0.2 extracted in:: 0:02:57.914902
# INFO: Extracting 84 points for chunk nr 14 at resolution 0.2
# INFO: 4 points for chunk nr 1 at resolution 0.2 extracted in:: 0:03:14.205518
# INFO: Extracting 64 points for chunk nr 15 at resolution 0.2
# INFO: 9 points for chunk nr 10 at resolution 0.2 extracted in:: 0:02:09.459880
# INFO: 46 points for chunk nr 7 at resolution 0.2 extracted in:: 0:04:16.869431
# INFO: 79 points for chunk nr 3 at resolution 0.2 extracted in:: 0:05:07.677263
# INFO: 1 points for chunk nr 12 at resolution 0.2 extracted in:: 0:03:13.661546
# INFO: 78 points for chunk nr 0 at resolution 0.2 extracted in:: 0:06:33.672218
# INFO: 64 points for chunk nr 15 at resolution 0.2 extracted in:: 0:03:17.754955
# INFO: 27 points for chunk nr 11 at resolution 0.2 extracted in:: 0:05:04.036157
# INFO: 1 points for chunk nr 13 at resolution 0.2 extracted in:: 0:04:07.959578
# INFO: 84 points for chunk nr 14 at resolution 0.2 extracted in:: 0:04:03.827048
# INFO: 94 points for chunk nr 8 at resolution 0.2 extracted in:: 0:07:14.520696
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_191832
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_191832.
# WARNING: Not fully processed. Will retry at a higher aggregation level.
# INFO: Checking for points not processed at the current aggregation level.
# INFO: Found already processed files. Identifying already processed points and skipping them.
# INFO: Found 638 already processed points
# INFO: Points not yet processed are uploaded to Earth Engine.
# INFO: Create AOI from points and upload as temporary EE asset inside tmp_esbae_231107_192953.
# INFO: Creating processing chunks of 0.15 degrees for parallel extraction.
# INFO: Preparing the parallel extraction over a total of 35 chunks. This may take a while...
# INFO: Starting the parallel extraction routine.
# INFO: Extracting 29 points for chunk nr 0 at resolution 0.15
# INFO: Extracting 12 points for chunk nr 5 at resolution 0.15
# INFO: Extracting 21 points for chunk nr 3 at resolution 0.15
# INFO: Extracting 41 points for chunk nr 4 at resolution 0.15
# INFO: Extracting 22 points for chunk nr 6 at resolution 0.15
# INFO: Extracting 9 points for chunk nr 1 at resolution 0.15
# INFO: Extracting 30 points for chunk nr 9 at resolution 0.15
# INFO: Extracting 76 points for chunk nr 8 at resolution 0.15
# INFO: Extracting 21 points for chunk nr 7 at resolution 0.15
# INFO: Extracting 93 points for chunk nr 2 at resolution 0.15
# INFO: 21 points for chunk nr 3 at resolution 0.15 extracted in:: 0:00:36.930221
# INFO: Extracting 78 points for chunk nr 10 at resolution 0.15
# INFO: 9 points for chunk nr 1 at resolution 0.15 extracted in:: 0:00:39.968829
# INFO: 21 points for chunk nr 7 at resolution 0.15 extracted in:: 0:00:40.634437
# INFO: Extracting 23 points for chunk nr 11 at resolution 0.15
# INFO: Extracting 5 points for chunk nr 12 at resolution 0.15
# INFO: 30 points for chunk nr 9 at resolution 0.15 extracted in:: 0:00:54.407783
# INFO: Extracting 2 points for chunk nr 13 at resolution 0.15
# INFO: 22 points for chunk nr 6 at resolution 0.15 extracted in:: 0:01:01.371746
# INFO: Extracting 12 points for chunk nr 14 at resolution 0.15
# INFO: 76 points for chunk nr 8 at resolution 0.15 extracted in:: 0:01:27.758569
# INFO: 29 points for chunk nr 0 at resolution 0.15 extracted in:: 0:01:28.595553
# INFO: Extracting 6 points for chunk nr 15 at resolution 0.15
# INFO: Extracting 92 points for chunk nr 16 at resolution 0.15
# INFO: 23 points for chunk nr 11 at resolution 0.15 extracted in:: 0:01:01.038482
# INFO: Extracting 48 points for chunk nr 17 at resolution 0.15
# INFO: 5 points for chunk nr 12 at resolution 0.15 extracted in:: 0:01:03.989892
# INFO: Extracting 44 points for chunk nr 18 at resolution 0.15
# INFO: 41 points for chunk nr 4 at resolution 0.15 extracted in:: 0:01:54.692669
# INFO: Extracting 21 points for chunk nr 19 at resolution 0.15
# INFO: 12 points for chunk nr 14 at resolution 0.15 extracted in:: 0:00:55.500767
# INFO: 6 points for chunk nr 15 at resolution 0.15 extracted in:: 0:00:28.870107
# INFO: Extracting 68 points for chunk nr 20 at resolution 0.15
# INFO: Extracting 64 points for chunk nr 21 at resolution 0.15
# INFO: 12 points for chunk nr 5 at resolution 0.15 extracted in:: 0:01:59.852080
# INFO: Extracting 68 points for chunk nr 22 at resolution 0.15
# INFO: 2 points for chunk nr 13 at resolution 0.15 extracted in:: 0:01:13.109729
# INFO: Extracting 58 points for chunk nr 23 at resolution 0.15
# INFO: 92 points for chunk nr 16 at resolution 0.15 extracted in:: 0:00:56.427622
# INFO: Extracting 51 points for chunk nr 24 at resolution 0.15
# INFO: 78 points for chunk nr 10 at resolution 0.15 extracted in:: 0:01:53.725433
# INFO: Extracting 51 points for chunk nr 25 at resolution 0.15
# INFO: 21 points for chunk nr 19 at resolution 0.15 extracted in:: 0:00:43.991132
# INFO: Extracting 48 points for chunk nr 26 at resolution 0.15
# INFO: 44 points for chunk nr 18 at resolution 0.15 extracted in:: 0:01:01.256142
# INFO: Extracting 41 points for chunk nr 27 at resolution 0.15
# INFO: 64 points for chunk nr 21 at resolution 0.15 extracted in:: 0:00:50.032947
# INFO: Extracting 32 points for chunk nr 28 at resolution 0.15
# INFO: 68 points for chunk nr 22 at resolution 0.15 extracted in:: 0:01:08.883952
# INFO: Extracting 34 points for chunk nr 29 at resolution 0.15
# INFO: 48 points for chunk nr 26 at resolution 0.15 extracted in:: 0:00:42.873209
# INFO: Extracting 33 points for chunk nr 30 at resolution 0.15
# INFO: 68 points for chunk nr 20 at resolution 0.15 extracted in:: 0:01:27.277187
# INFO: Extracting 16 points for chunk nr 31 at resolution 0.15
# INFO: 51 points for chunk nr 25 at resolution 0.15 extracted in:: 0:00:54.891372
# INFO: Extracting 17 points for chunk nr 32 at resolution 0.15
# INFO: 93 points for chunk nr 2 at resolution 0.15 extracted in:: 0:03:31.043912
# INFO: Extracting 16 points for chunk nr 33 at resolution 0.15
# INFO: 48 points for chunk nr 17 at resolution 0.15 extracted in:: 0:01:49.740653
# INFO: Extracting 5 points for chunk nr 34 at resolution 0.15
# INFO: 41 points for chunk nr 27 at resolution 0.15 extracted in:: 0:00:52.491848
# INFO: 32 points for chunk nr 28 at resolution 0.15 extracted in:: 0:00:52.701040
# INFO: 58 points for chunk nr 23 at resolution 0.15 extracted in:: 0:01:42.006738
# INFO: 51 points for chunk nr 24 at resolution 0.15 extracted in:: 0:01:36.427462
# INFO: 34 points for chunk nr 29 at resolution 0.15 extracted in:: 0:01:00.602657
# INFO: 16 points for chunk nr 31 at resolution 0.15 extracted in:: 0:00:56.038088
# INFO: 33 points for chunk nr 30 at resolution 0.15 extracted in:: 0:01:02.921194
# INFO: 5 points for chunk nr 34 at resolution 0.15 extracted in:: 0:01:11.106631
# INFO: 17 points for chunk nr 32 at resolution 0.15 extracted in:: 0:01:20.201683
# INFO: 16 points for chunk nr 33 at resolution 0.15 extracted in:: 0:02:37.150350
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_192953
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_192953.
# WARNING: Not fully processed. Will retry at a higher aggregation level.
# INFO: Checking for points not processed at the current aggregation level.
# INFO: Found already processed files. Identifying already processed points and skipping them.
# INFO: Found 1925 already processed points
# INFO: Points not yet processed are uploaded to Earth Engine.
# INFO: Create AOI from points and upload as temporary EE asset inside tmp_esbae_231107_193911.
# INFO: Creating processing chunks of 0.1 degrees for parallel extraction.
# INFO: Preparing the parallel extraction over a total of 82 chunks. This may take a while...
# INFO: Starting the parallel extraction routine.
# INFO: Extracting 66 points for chunk nr 9 at resolution 0.1
# INFO: Extracting 86 points for chunk nr 5 at resolution 0.1
# INFO: Extracting 78 points for chunk nr 1 at resolution 0.1
# INFO: Extracting 11 points for chunk nr 6 at resolution 0.1
# INFO: Extracting 44 points for chunk nr 8 at resolution 0.1
# INFO: Extracting 6 points for chunk nr 7 at resolution 0.1
# INFO: Extracting 63 points for chunk nr 4 at resolution 0.1
# INFO: Extracting 4 points for chunk nr 2 at resolution 0.1
# INFO: Extracting 2 points for chunk nr 3 at resolution 0.1
# INFO: Extracting 1 points for chunk nr 0 at resolution 0.1
# INFO: 1 points for chunk nr 0 at resolution 0.1 extracted in:: 0:00:28.830457
# INFO: Extracting 61 points for chunk nr 10 at resolution 0.1
# INFO: 6 points for chunk nr 7 at resolution 0.1 extracted in:: 0:00:32.620009
# INFO: 4 points for chunk nr 2 at resolution 0.1 extracted in:: 0:00:33.602525
# INFO: Extracting 36 points for chunk nr 11 at resolution 0.1
# INFO: Extracting 20 points for chunk nr 12 at resolution 0.1
# INFO: 44 points for chunk nr 8 at resolution 0.1 extracted in:: 0:00:40.950337
# INFO: Extracting 97 points for chunk nr 13 at resolution 0.1
# INFO: 66 points for chunk nr 9 at resolution 0.1 extracted in:: 0:01:03.631376
# INFO: Extracting 45 points for chunk nr 14 at resolution 0.1
# INFO: 2 points for chunk nr 3 at resolution 0.1 extracted in:: 0:01:16.747739
# INFO: Extracting 11 points for chunk nr 15 at resolution 0.1
# INFO: 36 points for chunk nr 11 at resolution 0.1 extracted in:: 0:00:55.980268
# INFO: Extracting 94 points for chunk nr 16 at resolution 0.1
# INFO: 61 points for chunk nr 10 at resolution 0.1 extracted in:: 0:01:01.765882
# INFO: Extracting 57 points for chunk nr 17 at resolution 0.1
# INFO: 78 points for chunk nr 1 at resolution 0.1 extracted in:: 0:01:44.953798
# INFO: Extracting 66 points for chunk nr 18 at resolution 0.1
# INFO: 86 points for chunk nr 5 at resolution 0.1 extracted in:: 0:02:12.221930
# INFO: Extracting 71 points for chunk nr 19 at resolution 0.1
# INFO: 20 points for chunk nr 12 at resolution 0.1 extracted in:: 0:01:40.944294
# INFO: Extracting 11 points for chunk nr 20 at resolution 0.1
# INFO: 57 points for chunk nr 17 at resolution 0.1 extracted in:: 0:00:52.496594
# INFO: Extracting 35 points for chunk nr 21 at resolution 0.1
# INFO: 11 points for chunk nr 15 at resolution 0.1 extracted in:: 0:01:11.703469
# INFO: Extracting 66 points for chunk nr 22 at resolution 0.1
# INFO: 11 points for chunk nr 6 at resolution 0.1 extracted in:: 0:02:38.763390
# INFO: Extracting 61 points for chunk nr 23 at resolution 0.1
# INFO: 63 points for chunk nr 4 at resolution 0.1 extracted in:: 0:02:46.201065
# INFO: Extracting 30 points for chunk nr 24 at resolution 0.1
# INFO: 66 points for chunk nr 18 at resolution 0.1 extracted in:: 0:01:01.737103
# INFO: Extracting 73 points for chunk nr 25 at resolution 0.1
# INFO: 45 points for chunk nr 14 at resolution 0.1 extracted in:: 0:01:50.896087
# INFO: Extracting 66 points for chunk nr 26 at resolution 0.1
# INFO: 94 points for chunk nr 16 at resolution 0.1 extracted in:: 0:01:33.385276
# INFO: Extracting 60 points for chunk nr 27 at resolution 0.1
# INFO: 97 points for chunk nr 13 at resolution 0.1 extracted in:: 0:02:35.448769
# INFO: Extracting 45 points for chunk nr 28 at resolution 0.1
# INFO: 11 points for chunk nr 20 at resolution 0.1 extracted in:: 0:01:19.957311
# INFO: Extracting 1 points for chunk nr 29 at resolution 0.1
# INFO: 30 points for chunk nr 24 at resolution 0.1 extracted in:: 0:00:50.121361
# INFO: Extracting 91 points for chunk nr 30 at resolution 0.1
# INFO: 73 points for chunk nr 25 at resolution 0.1 extracted in:: 0:00:50.524648
# INFO: 35 points for chunk nr 21 at resolution 0.1 extracted in:: 0:01:14.258060
# INFO: Extracting 55 points for chunk nr 31 at resolution 0.1
# INFO: Extracting 42 points for chunk nr 32 at resolution 0.1
# INFO: 61 points for chunk nr 23 at resolution 0.1 extracted in:: 0:01:08.911602
# INFO: Extracting 60 points for chunk nr 33 at resolution 0.1
# INFO: 66 points for chunk nr 22 at resolution 0.1 extracted in:: 0:01:27.832793
# INFO: Extracting 66 points for chunk nr 34 at resolution 0.1
# INFO: 71 points for chunk nr 19 at resolution 0.1 extracted in:: 0:02:15.084065
# INFO: Extracting 66 points for chunk nr 35 at resolution 0.1
# INFO: 42 points for chunk nr 32 at resolution 0.1 extracted in:: 0:01:07.717571
# INFO: Extracting 65 points for chunk nr 36 at resolution 0.1
# INFO: 60 points for chunk nr 33 at resolution 0.1 extracted in:: 0:01:18.791000
# INFO: Extracting 60 points for chunk nr 37 at resolution 0.1
# INFO: 55 points for chunk nr 31 at resolution 0.1 extracted in:: 0:01:30.131287
# INFO: Extracting 18 points for chunk nr 38 at resolution 0.1
# INFO: 66 points for chunk nr 35 at resolution 0.1 extracted in:: 0:01:00.444000
# INFO: Extracting 67 points for chunk nr 39 at resolution 0.1
# INFO: 1 points for chunk nr 29 at resolution 0.1 extracted in:: 0:02:01.305548
# INFO: Extracting 67 points for chunk nr 40 at resolution 0.1
# INFO: 66 points for chunk nr 34 at resolution 0.1 extracted in:: 0:01:42.451977
# INFO: Extracting 55 points for chunk nr 41 at resolution 0.1
# INFO: 66 points for chunk nr 26 at resolution 0.1 extracted in:: 0:02:56.712868
# INFO: Extracting 2 points for chunk nr 42 at resolution 0.1
# INFO: 65 points for chunk nr 36 at resolution 0.1 extracted in:: 0:01:05.668417
# INFO: Extracting 1 points for chunk nr 43 at resolution 0.1
# INFO: 18 points for chunk nr 38 at resolution 0.1 extracted in:: 0:01:03.389655
# INFO: Extracting 36 points for chunk nr 44 at resolution 0.1
# INFO: 60 points for chunk nr 37 at resolution 0.1 extracted in:: 0:01:13.202125
# INFO: Extracting 90 points for chunk nr 45 at resolution 0.1
# INFO: 67 points for chunk nr 39 at resolution 0.1 extracted in:: 0:00:56.889008
# INFO: Extracting 2 points for chunk nr 46 at resolution 0.1
# INFO: 91 points for chunk nr 30 at resolution 0.1 extracted in:: 0:03:02.142675
# INFO: Extracting 4 points for chunk nr 47 at resolution 0.1
# INFO: 2 points for chunk nr 42 at resolution 0.1 extracted in:: 0:00:50.136559
# INFO: Extracting 31 points for chunk nr 48 at resolution 0.1
# INFO: 1 points for chunk nr 43 at resolution 0.1 extracted in:: 0:00:53.141071
# INFO: Extracting 66 points for chunk nr 49 at resolution 0.1
# INFO: 2 points for chunk nr 46 at resolution 0.1 extracted in:: 0:00:38.155947
# INFO: Extracting 94 points for chunk nr 50 at resolution 0.1
# INFO: 4 points for chunk nr 47 at resolution 0.1 extracted in:: 0:00:26.767877
# INFO: Extracting 8 points for chunk nr 51 at resolution 0.1
# INFO: 90 points for chunk nr 45 at resolution 0.1 extracted in:: 0:01:15.570353
# INFO: Extracting 70 points for chunk nr 52 at resolution 0.1
# INFO: 45 points for chunk nr 28 at resolution 0.1 extracted in:: 0:04:21.902302
# INFO: Extracting 61 points for chunk nr 53 at resolution 0.1
# INFO: 60 points for chunk nr 27 at resolution 0.1 extracted in:: 0:05:07.609654
# INFO: Extracting 65 points for chunk nr 54 at resolution 0.1
# INFO: 36 points for chunk nr 44 at resolution 0.1 extracted in:: 0:02:08.365868
# INFO: Extracting 57 points for chunk nr 55 at resolution 0.1
# INFO: 55 points for chunk nr 41 at resolution 0.1 extracted in:: 0:02:45.646145
# INFO: Extracting 55 points for chunk nr 56 at resolution 0.1
# INFO: 8 points for chunk nr 51 at resolution 0.1 extracted in:: 0:01:26.892622
# INFO: Extracting 65 points for chunk nr 57 at resolution 0.1
# INFO: 67 points for chunk nr 40 at resolution 0.1 extracted in:: 0:03:28.043898
# INFO: Extracting 71 points for chunk nr 58 at resolution 0.1
# INFO: 31 points for chunk nr 48 at resolution 0.1 extracted in:: 0:02:38.929011
# INFO: Extracting 37 points for chunk nr 59 at resolution 0.1
# INFO: 55 points for chunk nr 56 at resolution 0.1 extracted in:: 0:01:07.445659
# INFO: Extracting 11 points for chunk nr 60 at resolution 0.1
# INFO: 94 points for chunk nr 50 at resolution 0.1 extracted in:: 0:02:31.054659
# INFO: Extracting 92 points for chunk nr 61 at resolution 0.1
# INFO: 57 points for chunk nr 55 at resolution 0.1 extracted in:: 0:01:14.475323
# INFO: 65 points for chunk nr 57 at resolution 0.1 extracted in:: 0:01:03.528593
# INFO: Extracting 73 points for chunk nr 62 at resolution 0.1
# INFO: Extracting 29 points for chunk nr 63 at resolution 0.1
# INFO: 61 points for chunk nr 53 at resolution 0.1 extracted in:: 0:02:22.540074
# INFO: Extracting 68 points for chunk nr 64 at resolution 0.1
# INFO: 71 points for chunk nr 58 at resolution 0.1 extracted in:: 0:00:56.869767
# INFO: Extracting 12 points for chunk nr 65 at resolution 0.1
# INFO: 66 points for chunk nr 49 at resolution 0.1 extracted in:: 0:03:24.171003
# INFO: Extracting 58 points for chunk nr 66 at resolution 0.1
# INFO: 70 points for chunk nr 52 at resolution 0.1 extracted in:: 0:02:59.129155
# INFO: Extracting 99 points for chunk nr 67 at resolution 0.1
# INFO: 12 points for chunk nr 65 at resolution 0.1 extracted in:: 0:00:45.053844
# INFO: Extracting 99 points for chunk nr 68 at resolution 0.1
# INFO: 11 points for chunk nr 60 at resolution 0.1 extracted in:: 0:01:23.549618
# INFO: Extracting 99 points for chunk nr 69 at resolution 0.1
# INFO: 29 points for chunk nr 63 at resolution 0.1 extracted in:: 0:01:25.387457
# INFO: Extracting 99 points for chunk nr 70 at resolution 0.1
# INFO: 37 points for chunk nr 59 at resolution 0.1 extracted in:: 0:01:54.520305
# INFO: Extracting 97 points for chunk nr 71 at resolution 0.1
# INFO: 68 points for chunk nr 64 at resolution 0.1 extracted in:: 0:01:21.866138
# INFO: Extracting 88 points for chunk nr 72 at resolution 0.1
# INFO: 92 points for chunk nr 61 at resolution 0.1 extracted in:: 0:02:07.707676
# INFO: Extracting 88 points for chunk nr 73 at resolution 0.1
# INFO: 58 points for chunk nr 66 at resolution 0.1 extracted in:: 0:01:38.615341
# INFO: Extracting 88 points for chunk nr 74 at resolution 0.1
# INFO: 65 points for chunk nr 54 at resolution 0.1 extracted in:: 0:03:45.177029
# INFO: Extracting 78 points for chunk nr 75 at resolution 0.1
# INFO: 99 points for chunk nr 67 at resolution 0.1 extracted in:: 0:01:51.185910
# INFO: Extracting 77 points for chunk nr 76 at resolution 0.1
# INFO: 99 points for chunk nr 69 at resolution 0.1 extracted in:: 0:02:39.508361
# INFO: Extracting 66 points for chunk nr 77 at resolution 0.1
# INFO: 99 points for chunk nr 68 at resolution 0.1 extracted in:: 0:03:01.013263
# INFO: Extracting 66 points for chunk nr 78 at resolution 0.1
# INFO: 73 points for chunk nr 62 at resolution 0.1 extracted in:: 0:04:30.521769
# INFO: Extracting 55 points for chunk nr 79 at resolution 0.1
# INFO: 77 points for chunk nr 76 at resolution 0.1 extracted in:: 0:02:21.793511
# INFO: Extracting 55 points for chunk nr 80 at resolution 0.1
# INFO: 88 points for chunk nr 73 at resolution 0.1 extracted in:: 0:03:18.611565
# INFO: Extracting 25 points for chunk nr 81 at resolution 0.1
# INFO: 66 points for chunk nr 78 at resolution 0.1 extracted in:: 0:01:16.491105
# INFO: 97 points for chunk nr 71 at resolution 0.1 extracted in:: 0:03:57.112330
# INFO: 88 points for chunk nr 72 at resolution 0.1 extracted in:: 0:03:59.617977
# INFO: 99 points for chunk nr 70 at resolution 0.1 extracted in:: 0:04:19.786262
# INFO: 88 points for chunk nr 74 at resolution 0.1 extracted in:: 0:03:36.487242
# INFO: 78 points for chunk nr 75 at resolution 0.1 extracted in:: 0:03:39.398412
# INFO: 55 points for chunk nr 79 at resolution 0.1 extracted in:: 0:01:35.999212
# INFO: 66 points for chunk nr 77 at resolution 0.1 extracted in:: 0:02:15.217823
# INFO: 25 points for chunk nr 81 at resolution 0.1 extracted in:: 0:00:54.000741
# INFO: 55 points for chunk nr 80 at resolution 0.1 extracted in:: 0:01:35.221446
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_193911
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_193911.
# WARNING: Not fully processed. Will retry at a higher aggregation level.
# INFO: Checking for points not processed at the current aggregation level.
# INFO: Found already processed files. Identifying already processed points and skipping them.
# INFO: Found 6341 already processed points
# INFO: Points not yet processed are uploaded to Earth Engine.
# INFO: ------------------------------------------------
# INFO: Processing subset 2/14
# INFO: ------------------------------------------------
# INFO: No time-series data has been extracted yet.
# INFO: Create AOI from points and upload as temporary EE asset inside tmp_esbae_231107_195839.
# INFO: Creating processing chunks of 0.2 degrees for parallel extraction.
# INFO: Preparing the parallel extraction over a total of 13 chunks. This may take a while...
# INFO: Starting the parallel extraction routine.
# INFO: Extracting 66 points for chunk nr 5 at resolution 0.2
# INFO: Extracting 98 points for chunk nr 1 at resolution 0.2
# INFO: Extracting 66 points for chunk nr 6 at resolution 0.2
# INFO: Extracting 44 points for chunk nr 8 at resolution 0.2
# INFO: Extracting 1 points for chunk nr 0 at resolution 0.2
# INFO: Extracting 88 points for chunk nr 2 at resolution 0.2
# INFO: Extracting 88 points for chunk nr 3 at resolution 0.2
# INFO: Extracting 39 points for chunk nr 9 at resolution 0.2
# INFO: Extracting 52 points for chunk nr 7 at resolution 0.2
# INFO: Extracting 78 points for chunk nr 4 at resolution 0.2
# INFO: 66 points for chunk nr 6 at resolution 0.2 extracted in:: 0:02:10.403805
# INFO: Extracting 22 points for chunk nr 10 at resolution 0.2
# INFO: 39 points for chunk nr 9 at resolution 0.2 extracted in:: 0:02:14.022495
# INFO: Extracting 22 points for chunk nr 11 at resolution 0.2
# INFO: 88 points for chunk nr 3 at resolution 0.2 extracted in:: 0:02:24.788570
# INFO: Extracting 4 points for chunk nr 12 at resolution 0.2
# INFO: 66 points for chunk nr 5 at resolution 0.2 extracted in:: 0:02:36.754815
# INFO: 78 points for chunk nr 4 at resolution 0.2 extracted in:: 0:02:48.437978
# INFO: 88 points for chunk nr 2 at resolution 0.2 extracted in:: 0:03:00.850506
# INFO: 1 points for chunk nr 0 at resolution 0.2 extracted in:: 0:03:09.469931
# INFO: 22 points for chunk nr 10 at resolution 0.2 extracted in:: 0:02:15.972539
# INFO: 52 points for chunk nr 7 at resolution 0.2 extracted in:: 0:04:35.039669
# INFO: 44 points for chunk nr 8 at resolution 0.2 extracted in:: 0:04:57.017633
# INFO: 22 points for chunk nr 11 at resolution 0.2 extracted in:: 0:02:43.518265
# INFO: 4 points for chunk nr 12 at resolution 0.2 extracted in:: 0:02:45.457674
# INFO: 98 points for chunk nr 1 at resolution 0.2 extracted in:: 0:06:02.226706
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_195839
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_195839.
# WARNING: Not fully processed. Will retry at a higher aggregation level.
# INFO: Checking for points not processed at the current aggregation level.
# INFO: Found already processed files. Identifying already processed points and skipping them.
# INFO: Found 668 already processed points
# INFO: Points not yet processed are uploaded to Earth Engine.
# INFO: Create AOI from points and upload as temporary EE asset inside tmp_esbae_231107_200914.
# INFO: Creating processing chunks of 0.15 degrees for parallel extraction.
# INFO: Preparing the parallel extraction over a total of 39 chunks. This may take a while...
# INFO: Starting the parallel extraction routine.
# INFO: Extracting 51 points for chunk nr 7 at resolution 0.15
# INFO: Extracting 16 points for chunk nr 1 at resolution 0.15
# INFO: Extracting 34 points for chunk nr 4 at resolution 0.15
# INFO: Extracting 17 points for chunk nr 2 at resolution 0.15
# INFO: Extracting 22 points for chunk nr 3 at resolution 0.15
# INFO: Extracting 48 points for chunk nr 8 at resolution 0.15
# INFO: Extracting 43 points for chunk nr 6 at resolution 0.15
# INFO: Extracting 32 points for chunk nr 5 at resolution 0.15
# INFO: Extracting 6 points for chunk nr 0 at resolution 0.15
# INFO: Extracting 77 points for chunk nr 9 at resolution 0.15
# INFO: 6 points for chunk nr 0 at resolution 0.15 extracted in:: 0:00:35.494094
# INFO: Extracting 80 points for chunk nr 10 at resolution 0.15
# INFO: 16 points for chunk nr 1 at resolution 0.15 extracted in:: 0:00:44.466715
# INFO: Extracting 89 points for chunk nr 11 at resolution 0.15
# INFO: 17 points for chunk nr 2 at resolution 0.15 extracted in:: 0:00:45.774683
# INFO: Extracting 6 points for chunk nr 12 at resolution 0.15
# INFO: 22 points for chunk nr 3 at resolution 0.15 extracted in:: 0:01:01.112799
# INFO: Extracting 37 points for chunk nr 13 at resolution 0.15
# INFO: 34 points for chunk nr 4 at resolution 0.15 extracted in:: 0:01:41.938786
# INFO: Extracting 76 points for chunk nr 14 at resolution 0.15
# INFO: 37 points for chunk nr 13 at resolution 0.15 extracted in:: 0:00:43.925313
# INFO: Extracting 79 points for chunk nr 15 at resolution 0.15
# INFO: 77 points for chunk nr 9 at resolution 0.15 extracted in:: 0:02:10.146974
# INFO: Extracting 69 points for chunk nr 16 at resolution 0.15
# INFO: 32 points for chunk nr 5 at resolution 0.15 extracted in:: 0:02:17.256461
# INFO: Extracting 70 points for chunk nr 17 at resolution 0.15
# INFO: 6 points for chunk nr 12 at resolution 0.15 extracted in:: 0:01:39.874226
# INFO: Extracting 1 points for chunk nr 18 at resolution 0.15
# INFO: 79 points for chunk nr 15 at resolution 0.15 extracted in:: 0:00:50.116303
# INFO: Extracting 88 points for chunk nr 19 at resolution 0.15
# INFO: 51 points for chunk nr 7 at resolution 0.15 extracted in:: 0:02:43.409634
# INFO: 89 points for chunk nr 11 at resolution 0.15 extracted in:: 0:01:57.951078
# INFO: Extracting 94 points for chunk nr 21 at resolution 0.15
# INFO: Extracting 80 points for chunk nr 20 at resolution 0.15
# INFO: 1 points for chunk nr 18 at resolution 0.15 extracted in:: 0:00:35.265278
# INFO: Extracting 85 points for chunk nr 22 at resolution 0.15
# INFO: 48 points for chunk nr 8 at resolution 0.15 extracted in:: 0:03:10.193912
# INFO: Extracting 91 points for chunk nr 23 at resolution 0.15
# INFO: 80 points for chunk nr 10 at resolution 0.15 extracted in:: 0:02:38.959271
# INFO: 70 points for chunk nr 17 at resolution 0.15 extracted in:: 0:00:58.720424
# INFO: Extracting 96 points for chunk nr 24 at resolution 0.15
# INFO: Extracting 91 points for chunk nr 25 at resolution 0.15
# INFO: 76 points for chunk nr 14 at resolution 0.15 extracted in:: 0:02:01.930318
# INFO: Extracting 80 points for chunk nr 26 at resolution 0.15
# INFO: 94 points for chunk nr 21 at resolution 0.15 extracted in:: 0:01:05.698153
# INFO: Extracting 95 points for chunk nr 27 at resolution 0.15
# INFO: 80 points for chunk nr 20 at resolution 0.15 extracted in:: 0:01:12.654929
# INFO: Extracting 80 points for chunk nr 28 at resolution 0.15
# INFO: 88 points for chunk nr 19 at resolution 0.15 extracted in:: 0:01:27.605735
# INFO: Extracting 98 points for chunk nr 29 at resolution 0.15
# INFO: 85 points for chunk nr 22 at resolution 0.15 extracted in:: 0:01:09.222325
# INFO: Extracting 91 points for chunk nr 30 at resolution 0.15
# INFO: 69 points for chunk nr 16 at resolution 0.15 extracted in:: 0:02:12.089967
# INFO: Extracting 85 points for chunk nr 31 at resolution 0.15
# INFO: 43 points for chunk nr 6 at resolution 0.15 extracted in:: 0:04:47.787052
# INFO: Extracting 80 points for chunk nr 32 at resolution 0.15
# INFO: 80 points for chunk nr 28 at resolution 0.15 extracted in:: 0:01:11.141136
# INFO: Extracting 78 points for chunk nr 33 at resolution 0.15
# INFO: 91 points for chunk nr 23 at resolution 0.15 extracted in:: 0:02:00.419313
# INFO: Extracting 68 points for chunk nr 34 at resolution 0.15
# INFO: 80 points for chunk nr 26 at resolution 0.15 extracted in:: 0:01:32.401972
# INFO: Extracting 64 points for chunk nr 35 at resolution 0.15
# INFO: 95 points for chunk nr 27 at resolution 0.15 extracted in:: 0:01:29.996264
# INFO: Extracting 58 points for chunk nr 36 at resolution 0.15
# INFO: 96 points for chunk nr 24 at resolution 0.15 extracted in:: 0:02:15.578936
# INFO: Extracting 48 points for chunk nr 37 at resolution 0.15
# INFO: 91 points for chunk nr 30 at resolution 0.15 extracted in:: 0:01:28.178432
# INFO: Extracting 48 points for chunk nr 38 at resolution 0.15
# INFO: 85 points for chunk nr 31 at resolution 0.15 extracted in:: 0:01:31.261750
# INFO: 91 points for chunk nr 25 at resolution 0.15 extracted in:: 0:02:41.232603
# INFO: 98 points for chunk nr 29 at resolution 0.15 extracted in:: 0:02:25.277780
# INFO: 48 points for chunk nr 37 at resolution 0.15 extracted in:: 0:01:05.146326
# INFO: 48 points for chunk nr 38 at resolution 0.15 extracted in:: 0:00:59.115104
# INFO: 58 points for chunk nr 36 at resolution 0.15 extracted in:: 0:01:22.042336
# INFO: 80 points for chunk nr 32 at resolution 0.15 extracted in:: 0:02:21.830172
# INFO: 68 points for chunk nr 34 at resolution 0.15 extracted in:: 0:02:46.786999
# INFO: 78 points for chunk nr 33 at resolution 0.15 extracted in:: 0:02:55.079423
# INFO: 64 points for chunk nr 35 at resolution 0.15 extracted in:: 0:04:05.561095
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_200914
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_200914.
# WARNING: Not fully processed. Will retry at a higher aggregation level.
# INFO: Checking for points not processed at the current aggregation level.
# INFO: Found already processed files. Identifying already processed points and skipping them.
# INFO: Found 3119 already processed points
# INFO: Points not yet processed are uploaded to Earth Engine.
# INFO: Create AOI from points and upload as temporary EE asset inside tmp_esbae_231107_202108.
# INFO: Creating processing chunks of 0.1 degrees for parallel extraction.
# INFO: Preparing the parallel extraction over a total of 114 chunks. This may take a while...
# INFO: Starting the parallel extraction routine.
# INFO: Extracting 1 points for chunk nr 0 at resolution 0.1
# INFO: Extracting 11 points for chunk nr 1 at resolution 0.1
# INFO: Extracting 22 points for chunk nr 7 at resolution 0.1
# INFO: Extracting 11 points for chunk nr 2 at resolution 0.1
# INFO: Extracting 22 points for chunk nr 4 at resolution 0.1
# INFO: Extracting 22 points for chunk nr 6 at resolution 0.1
# INFO: Extracting 22 points for chunk nr 8 at resolution 0.1
# INFO: Extracting 22 points for chunk nr 5 at resolution 0.1
# INFO: Extracting 27 points for chunk nr 9 at resolution 0.1
# INFO: Extracting 18 points for chunk nr 3 at resolution 0.1
# INFO: 18 points for chunk nr 3 at resolution 0.1 extracted in:: 0:00:32.590348
# INFO: Extracting 33 points for chunk nr 10 at resolution 0.1
# INFO: 22 points for chunk nr 4 at resolution 0.1 extracted in:: 0:00:37.309248
# INFO: Extracting 33 points for chunk nr 11 at resolution 0.1
# INFO: 11 points for chunk nr 2 at resolution 0.1 extracted in:: 0:00:40.548844
# INFO: 1 points for chunk nr 0 at resolution 0.1 extracted in:: 0:00:42.295728
# INFO: Extracting 33 points for chunk nr 12 at resolution 0.1
# INFO: Extracting 33 points for chunk nr 13 at resolution 0.1
# INFO: 27 points for chunk nr 9 at resolution 0.1 extracted in:: 0:00:49.561794
# INFO: 11 points for chunk nr 1 at resolution 0.1 extracted in:: 0:00:50.795735
# INFO: Extracting 33 points for chunk nr 14 at resolution 0.1
# INFO: Extracting 43 points for chunk nr 15 at resolution 0.1
# INFO: 22 points for chunk nr 6 at resolution 0.1 extracted in:: 0:01:04.598340
# INFO: Extracting 44 points for chunk nr 16 at resolution 0.1
# INFO: 22 points for chunk nr 5 at resolution 0.1 extracted in:: 0:01:07.838621
# INFO: Extracting 44 points for chunk nr 17 at resolution 0.1
# INFO: 33 points for chunk nr 10 at resolution 0.1 extracted in:: 0:00:41.244386
# INFO: Extracting 44 points for chunk nr 18 at resolution 0.1
# INFO: 22 points for chunk nr 7 at resolution 0.1 extracted in:: 0:01:19.437100
# INFO: Extracting 44 points for chunk nr 19 at resolution 0.1
# INFO: 33 points for chunk nr 11 at resolution 0.1 extracted in:: 0:00:48.039127
# INFO: Extracting 56 points for chunk nr 20 at resolution 0.1
# INFO: 33 points for chunk nr 12 at resolution 0.1 extracted in:: 0:01:00.532096
# INFO: Extracting 55 points for chunk nr 21 at resolution 0.1
# INFO: 44 points for chunk nr 16 at resolution 0.1 extracted in:: 0:00:41.826671
# INFO: 43 points for chunk nr 15 at resolution 0.1 extracted in:: 0:00:56.630430
# INFO: Extracting 55 points for chunk nr 22 at resolution 0.1
# INFO: Extracting 55 points for chunk nr 23 at resolution 0.1
# INFO: 44 points for chunk nr 17 at resolution 0.1 extracted in:: 0:00:43.011282
# INFO: Extracting 55 points for chunk nr 24 at resolution 0.1
# INFO: 22 points for chunk nr 8 at resolution 0.1 extracted in:: 0:01:55.361984
# INFO: 33 points for chunk nr 13 at resolution 0.1 extracted in:: 0:01:13.055590
# INFO: Extracting 65 points for chunk nr 25 at resolution 0.1
# INFO: Extracting 66 points for chunk nr 26 at resolution 0.1
# INFO: 44 points for chunk nr 18 at resolution 0.1 extracted in:: 0:01:05.755700
# INFO: Extracting 60 points for chunk nr 27 at resolution 0.1
# INFO: 44 points for chunk nr 19 at resolution 0.1 extracted in:: 0:01:06.943892
# INFO: 33 points for chunk nr 14 at resolution 0.1 extracted in:: 0:01:39.447007
# INFO: Extracting 55 points for chunk nr 28 at resolution 0.1
# INFO: Extracting 58 points for chunk nr 29 at resolution 0.1
# INFO: 55 points for chunk nr 24 at resolution 0.1 extracted in:: 0:00:49.648537
# INFO: Extracting 66 points for chunk nr 30 at resolution 0.1
# INFO: 66 points for chunk nr 26 at resolution 0.1 extracted in:: 0:01:08.535522
# INFO: Extracting 65 points for chunk nr 31 at resolution 0.1
# INFO: 56 points for chunk nr 20 at resolution 0.1 extracted in:: 0:02:00.889158
# INFO: Extracting 55 points for chunk nr 32 at resolution 0.1
# INFO: 55 points for chunk nr 28 at resolution 0.1 extracted in:: 0:00:58.903009
# INFO: Extracting 55 points for chunk nr 33 at resolution 0.1
# INFO: 55 points for chunk nr 23 at resolution 0.1 extracted in:: 0:01:55.815564
# INFO: Extracting 65 points for chunk nr 34 at resolution 0.1
# INFO: 66 points for chunk nr 30 at resolution 0.1 extracted in:: 0:01:03.614984
# INFO: Extracting 66 points for chunk nr 35 at resolution 0.1
# INFO: 58 points for chunk nr 29 at resolution 0.1 extracted in:: 0:01:17.876028
# INFO: Extracting 62 points for chunk nr 36 at resolution 0.1
# INFO: 65 points for chunk nr 25 at resolution 0.1 extracted in:: 0:01:53.696209
# INFO: Extracting 55 points for chunk nr 37 at resolution 0.1
# INFO: 60 points for chunk nr 27 at resolution 0.1 extracted in:: 0:01:31.047439
# INFO: Extracting 64 points for chunk nr 38 at resolution 0.1
# INFO: 55 points for chunk nr 21 at resolution 0.1 extracted in:: 0:02:30.737055
# INFO: 55 points for chunk nr 22 at resolution 0.1 extracted in:: 0:02:26.258363
# INFO: Extracting 66 points for chunk nr 39 at resolution 0.1
# INFO: Extracting 57 points for chunk nr 40 at resolution 0.1
# INFO: 65 points for chunk nr 31 at resolution 0.1 extracted in:: 0:01:13.836842
# INFO: Extracting 55 points for chunk nr 41 at resolution 0.1
# INFO: 55 points for chunk nr 32 at resolution 0.1 extracted in:: 0:01:16.259903
# INFO: Extracting 64 points for chunk nr 42 at resolution 0.1
# INFO: 55 points for chunk nr 33 at resolution 0.1 extracted in:: 0:01:23.096356
# INFO: Extracting 66 points for chunk nr 43 at resolution 0.1
# INFO: 65 points for chunk nr 34 at resolution 0.1 extracted in:: 0:02:17.280648
# INFO: Extracting 92 points for chunk nr 44 at resolution 0.1
# INFO: 64 points for chunk nr 38 at resolution 0.1 extracted in:: 0:02:28.482781
# INFO: Extracting 83 points for chunk nr 45 at resolution 0.1
# INFO: 66 points for chunk nr 39 at resolution 0.1 extracted in:: 0:02:14.544288
# INFO: Extracting 79 points for chunk nr 46 at resolution 0.1
# INFO: 62 points for chunk nr 36 at resolution 0.1 extracted in:: 0:02:41.455431
# INFO: Extracting 87 points for chunk nr 47 at resolution 0.1
# INFO: 55 points for chunk nr 41 at resolution 0.1 extracted in:: 0:02:11.658664
# INFO: Extracting 96 points for chunk nr 48 at resolution 0.1
# INFO: 66 points for chunk nr 43 at resolution 0.1 extracted in:: 0:02:02.321937
# INFO: Extracting 65 points for chunk nr 49 at resolution 0.1
# INFO: 57 points for chunk nr 40 at resolution 0.1 extracted in:: 0:02:50.943546
# INFO: Extracting 85 points for chunk nr 50 at resolution 0.1
# INFO: 64 points for chunk nr 42 at resolution 0.1 extracted in:: 0:02:45.759668
# INFO: Extracting 17 points for chunk nr 51 at resolution 0.1
# INFO: 83 points for chunk nr 45 at resolution 0.1 extracted in:: 0:01:09.160265
# INFO: Extracting 43 points for chunk nr 52 at resolution 0.1
# INFO: 96 points for chunk nr 48 at resolution 0.1 extracted in:: 0:01:05.620226
# INFO: 79 points for chunk nr 46 at resolution 0.1 extracted in:: 0:01:09.841002
# INFO: 66 points for chunk nr 35 at resolution 0.1 extracted in:: 0:03:52.362748
# INFO: Extracting 4 points for chunk nr 53 at resolution 0.1
# INFO: Extracting 20 points for chunk nr 54 at resolution 0.1
# INFO: Extracting 52 points for chunk nr 55 at resolution 0.1
# INFO: 87 points for chunk nr 47 at resolution 0.1 extracted in:: 0:01:16.338036
# INFO: Extracting 55 points for chunk nr 56 at resolution 0.1
# INFO: 85 points for chunk nr 50 at resolution 0.1 extracted in:: 0:00:56.565367
# INFO: Extracting 88 points for chunk nr 57 at resolution 0.1
# INFO: 4 points for chunk nr 53 at resolution 0.1 extracted in:: 0:00:35.468431
# INFO: Extracting 66 points for chunk nr 58 at resolution 0.1
# INFO: 65 points for chunk nr 49 at resolution 0.1 extracted in:: 0:01:20.541821
# INFO: Extracting 66 points for chunk nr 59 at resolution 0.1
# INFO: 20 points for chunk nr 54 at resolution 0.1 extracted in:: 0:00:38.158604
# INFO: 17 points for chunk nr 51 at resolution 0.1 extracted in:: 0:00:47.211375
# INFO: Extracting 97 points for chunk nr 60 at resolution 0.1
# INFO: Extracting 55 points for chunk nr 61 at resolution 0.1
# INFO: 43 points for chunk nr 52 at resolution 0.1 extracted in:: 0:00:48.223855
# INFO: Extracting 63 points for chunk nr 62 at resolution 0.1
# INFO: 52 points for chunk nr 55 at resolution 0.1 extracted in:: 0:00:48.480876
# INFO: Extracting 66 points for chunk nr 63 at resolution 0.1
# INFO: 92 points for chunk nr 44 at resolution 0.1 extracted in:: 0:02:42.984041
# INFO: Extracting 66 points for chunk nr 64 at resolution 0.1
# INFO: 55 points for chunk nr 37 at resolution 0.1 extracted in:: 0:05:04.501324
# INFO: Extracting 60 points for chunk nr 65 at resolution 0.1
# INFO: 55 points for chunk nr 61 at resolution 0.1 extracted in:: 0:00:44.478215
# INFO: Extracting 55 points for chunk nr 66 at resolution 0.1
# INFO: 66 points for chunk nr 58 at resolution 0.1 extracted in:: 0:00:58.718169
# INFO: Extracting 61 points for chunk nr 67 at resolution 0.1
# INFO: 97 points for chunk nr 60 at resolution 0.1 extracted in:: 0:01:06.583646
# INFO: Extracting 66 points for chunk nr 68 at resolution 0.1
# INFO: 66 points for chunk nr 59 at resolution 0.1 extracted in:: 0:01:09.990237
# INFO: Extracting 71 points for chunk nr 69 at resolution 0.1
# INFO: 66 points for chunk nr 63 at resolution 0.1 extracted in:: 0:01:03.878235
# INFO: Extracting 85 points for chunk nr 70 at resolution 0.1
# INFO: 66 points for chunk nr 64 at resolution 0.1 extracted in:: 0:00:49.900730
# INFO: Extracting 62 points for chunk nr 71 at resolution 0.1
# INFO: 88 points for chunk nr 57 at resolution 0.1 extracted in:: 0:01:40.981383
# INFO: Extracting 66 points for chunk nr 72 at resolution 0.1
# INFO: 63 points for chunk nr 62 at resolution 0.1 extracted in:: 0:01:36.460002
# INFO: Extracting 63 points for chunk nr 73 at resolution 0.1
# INFO: 55 points for chunk nr 56 at resolution 0.1 extracted in:: 0:02:31.212341
# INFO: Extracting 55 points for chunk nr 74 at resolution 0.1
# INFO: 85 points for chunk nr 70 at resolution 0.1 extracted in:: 0:01:02.935277
# INFO: Extracting 55 points for chunk nr 75 at resolution 0.1
# INFO: 62 points for chunk nr 71 at resolution 0.1 extracted in:: 0:01:09.295848
# INFO: Extracting 66 points for chunk nr 76 at resolution 0.1
# INFO: 71 points for chunk nr 69 at resolution 0.1 extracted in:: 0:01:22.395547
# INFO: Extracting 66 points for chunk nr 77 at resolution 0.1
# INFO: 66 points for chunk nr 68 at resolution 0.1 extracted in:: 0:01:27.705579
# INFO: Extracting 57 points for chunk nr 78 at resolution 0.1
# INFO: 55 points for chunk nr 66 at resolution 0.1 extracted in:: 0:01:54.771636
# INFO: Extracting 55 points for chunk nr 79 at resolution 0.1
# INFO: 66 points for chunk nr 72 at resolution 0.1 extracted in:: 0:01:16.125297
# INFO: 63 points for chunk nr 73 at resolution 0.1 extracted in:: 0:01:02.859825
# INFO: Extracting 68 points for chunk nr 80 at resolution 0.1
# INFO: Extracting 66 points for chunk nr 81 at resolution 0.1
# INFO: 60 points for chunk nr 65 at resolution 0.1 extracted in:: 0:02:13.408360
# INFO: 61 points for chunk nr 67 at resolution 0.1 extracted in:: 0:01:53.208535
# INFO: Extracting 59 points for chunk nr 82 at resolution 0.1
# INFO: Extracting 55 points for chunk nr 83 at resolution 0.1
# INFO: 55 points for chunk nr 74 at resolution 0.1 extracted in:: 0:00:58.053634
# INFO: Extracting 60 points for chunk nr 84 at resolution 0.1
# INFO: 55 points for chunk nr 75 at resolution 0.1 extracted in:: 0:00:54.306003
# INFO: Extracting 66 points for chunk nr 85 at resolution 0.1
# INFO: 66 points for chunk nr 76 at resolution 0.1 extracted in:: 0:01:02.532144
# INFO: Extracting 60 points for chunk nr 86 at resolution 0.1
# INFO: 57 points for chunk nr 78 at resolution 0.1 extracted in:: 0:01:03.842367
# INFO: Extracting 55 points for chunk nr 87 at resolution 0.1
# INFO: 66 points for chunk nr 77 at resolution 0.1 extracted in:: 0:01:19.191250
# INFO: Extracting 60 points for chunk nr 88 at resolution 0.1
# INFO: 60 points for chunk nr 84 at resolution 0.1 extracted in:: 0:01:07.630871
# INFO: Extracting 19 points for chunk nr 89 at resolution 0.1
# INFO: 66 points for chunk nr 85 at resolution 0.1 extracted in:: 0:01:03.953343
# INFO: Extracting 59 points for chunk nr 90 at resolution 0.1
# INFO: 55 points for chunk nr 83 at resolution 0.1 extracted in:: 0:01:29.596678
# INFO: Extracting 86 points for chunk nr 91 at resolution 0.1
# INFO: 60 points for chunk nr 86 at resolution 0.1 extracted in:: 0:01:14.330160
# INFO: Extracting 77 points for chunk nr 92 at resolution 0.1
# INFO: 55 points for chunk nr 87 at resolution 0.1 extracted in:: 0:01:07.300878
# INFO: Extracting 77 points for chunk nr 93 at resolution 0.1
# INFO: 55 points for chunk nr 79 at resolution 0.1 extracted in:: 0:02:10.063092
# INFO: Extracting 77 points for chunk nr 94 at resolution 0.1
# INFO: 68 points for chunk nr 80 at resolution 0.1 extracted in:: 0:02:13.248326
# INFO: Extracting 77 points for chunk nr 95 at resolution 0.1
# INFO: 59 points for chunk nr 82 at resolution 0.1 extracted in:: 0:02:14.109254
# INFO: Extracting 77 points for chunk nr 96 at resolution 0.1
# INFO: 19 points for chunk nr 89 at resolution 0.1 extracted in:: 0:01:14.474002
# INFO: Extracting 77 points for chunk nr 97 at resolution 0.1
# INFO: 66 points for chunk nr 81 at resolution 0.1 extracted in:: 0:02:43.459813
# INFO: Extracting 77 points for chunk nr 98 at resolution 0.1
# INFO: 60 points for chunk nr 88 at resolution 0.1 extracted in:: 0:01:42.679847
# INFO: Extracting 66 points for chunk nr 99 at resolution 0.1
# INFO: 59 points for chunk nr 90 at resolution 0.1 extracted in:: 0:01:43.118944
# INFO: Extracting 66 points for chunk nr 100 at resolution 0.1
# INFO: 86 points for chunk nr 91 at resolution 0.1 extracted in:: 0:01:48.419910
# INFO: Extracting 66 points for chunk nr 101 at resolution 0.1
# INFO: 77 points for chunk nr 92 at resolution 0.1 extracted in:: 0:01:28.504354
# INFO: Extracting 66 points for chunk nr 102 at resolution 0.1
# INFO: 77 points for chunk nr 97 at resolution 0.1 extracted in:: 0:00:54.190544
# INFO: Extracting 66 points for chunk nr 103 at resolution 0.1
# INFO: 77 points for chunk nr 98 at resolution 0.1 extracted in:: 0:00:54.165638
# INFO: Extracting 66 points for chunk nr 104 at resolution 0.1
# INFO: 77 points for chunk nr 93 at resolution 0.1 extracted in:: 0:01:42.603393
# INFO: Extracting 66 points for chunk nr 105 at resolution 0.1
# INFO: 66 points for chunk nr 99 at resolution 0.1 extracted in:: 0:01:05.336764
# INFO: Extracting 57 points for chunk nr 106 at resolution 0.1
# INFO: 66 points for chunk nr 102 at resolution 0.1 extracted in:: 0:00:48.687287
# INFO: Extracting 60 points for chunk nr 107 at resolution 0.1
# INFO: 66 points for chunk nr 100 at resolution 0.1 extracted in:: 0:01:04.000333
# INFO: Extracting 55 points for chunk nr 108 at resolution 0.1
# INFO: 66 points for chunk nr 101 at resolution 0.1 extracted in:: 0:00:59.045504
# INFO: Extracting 55 points for chunk nr 109 at resolution 0.1
# INFO: 77 points for chunk nr 94 at resolution 0.1 extracted in:: 0:02:24.586394
# INFO: Extracting 55 points for chunk nr 110 at resolution 0.1
# INFO: 66 points for chunk nr 105 at resolution 0.1 extracted in:: 0:00:47.605196
# INFO: Extracting 55 points for chunk nr 111 at resolution 0.1
# INFO: 66 points for chunk nr 103 at resolution 0.1 extracted in:: 0:01:02.834649
# INFO: Extracting 50 points for chunk nr 112 at resolution 0.1
# INFO: 77 points for chunk nr 96 at resolution 0.1 extracted in:: 0:02:17.911644
# INFO: Extracting 20 points for chunk nr 113 at resolution 0.1
# INFO: 66 points for chunk nr 104 at resolution 0.1 extracted in:: 0:01:08.250602
# INFO: 77 points for chunk nr 95 at resolution 0.1 extracted in:: 0:02:35.844152
# INFO: 57 points for chunk nr 106 at resolution 0.1 extracted in:: 0:00:55.546703
# INFO: 20 points for chunk nr 113 at resolution 0.1 extracted in:: 0:00:40.665263
# INFO: 60 points for chunk nr 107 at resolution 0.1 extracted in:: 0:01:01.890798
# INFO: 50 points for chunk nr 112 at resolution 0.1 extracted in:: 0:00:52.079347
# INFO: 55 points for chunk nr 108 at resolution 0.1 extracted in:: 0:01:09.481081
# INFO: 55 points for chunk nr 111 at resolution 0.1 extracted in:: 0:01:41.324815
# ...
# INFO: 90 points for chunk nr 72 at resolution 0.1 extracted in:: 0:01:06.865309
# INFO: Extracting 55 points for chunk nr 78 at resolution 0.1
# INFO: 96 points for chunk nr 73 at resolution 0.1 extracted in:: 0:00:54.701801
# INFO: Extracting 85 points for chunk nr 79 at resolution 0.1
# INFO: 40 points for chunk nr 74 at resolution 0.1 extracted in:: 0:01:07.780884
# INFO: Extracting 47 points for chunk nr 80 at resolution 0.1
# INFO: 54 points for chunk nr 68 at resolution 0.1 extracted in:: 0:02:10.075866
# INFO: Extracting 9 points for chunk nr 81 at resolution 0.1
# INFO: 78 points for chunk nr 76 at resolution 0.1 extracted in:: 0:01:04.453501
# INFO: Extracting 25 points for chunk nr 82 at resolution 0.1
# INFO: 49 points for chunk nr 71 at resolution 0.1 extracted in:: 0:01:54.869773
# INFO: Extracting 33 points for chunk nr 83 at resolution 0.1
# INFO: 69 points for chunk nr 75 at resolution 0.1 extracted in:: 0:01:38.164976
# INFO: Extracting 33 points for chunk nr 84 at resolution 0.1
# INFO: 2 points for chunk nr 77 at resolution 0.1 extracted in:: 0:01:13.711267
# INFO: Extracting 33 points for chunk nr 85 at resolution 0.1
# INFO: 66 points for chunk nr 67 at resolution 0.1 extracted in:: 0:02:51.432149
# INFO: Extracting 36 points for chunk nr 86 at resolution 0.1
# INFO: 85 points for chunk nr 79 at resolution 0.1 extracted in:: 0:01:11.209572
# INFO: Extracting 28 points for chunk nr 87 at resolution 0.1
# INFO: 91 points for chunk nr 66 at resolution 0.1 extracted in:: 0:03:19.335776
# INFO: Extracting 13 points for chunk nr 88 at resolution 0.1
# INFO: 47 points for chunk nr 80 at resolution 0.1 extracted in:: 0:01:02.113773
# INFO: Extracting 11 points for chunk nr 89 at resolution 0.1
# INFO: 9 points for chunk nr 81 at resolution 0.1 extracted in:: 0:01:00.546499
# INFO: Extracting 5 points for chunk nr 90 at resolution 0.1
# INFO: 33 points for chunk nr 84 at resolution 0.1 extracted in:: 0:00:51.807733
# INFO: 36 points for chunk nr 86 at resolution 0.1 extracted in:: 0:00:49.084651
# INFO: 55 points for chunk nr 78 at resolution 0.1 extracted in:: 0:01:53.418465
# INFO: 13 points for chunk nr 88 at resolution 0.1 extracted in:: 0:00:36.884525
# INFO: 33 points for chunk nr 83 at resolution 0.1 extracted in:: 0:01:12.583807
# INFO: 28 points for chunk nr 87 at resolution 0.1 extracted in:: 0:00:47.529920
# INFO: 33 points for chunk nr 85 at resolution 0.1 extracted in:: 0:01:08.009821
# INFO: 11 points for chunk nr 89 at resolution 0.1 extracted in:: 0:00:41.695465
# INFO: 25 points for chunk nr 82 at resolution 0.1 extracted in:: 0:01:20.390421
# INFO: 5 points for chunk nr 90 at resolution 0.1 extracted in:: 0:00:37.431366
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_033054
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_033054.
# WARNING: Not fully processed. Will retry at a higher aggregation level.
# INFO: Checking for points not processed at the current aggregation level.
# INFO: Found already processed files. Identifying already processed points and skipping them.
# INFO: Found 7632 already processed points
# INFO: Points not yet processed are uploaded to Earth Engine.
# INFO: ------------------------------------------------
# INFO: Processing subset 14/14
# INFO: ------------------------------------------------
# INFO: No time-series data has been extracted yet.
# INFO: Create AOI from points and upload as temporary EE asset inside tmp_esbae_231108_034703.
# INFO: Creating processing chunks of 0.2 degrees for parallel extraction.
# INFO: Preparing the parallel extraction over a total of 3 chunks. This may take a while...
# INFO: Starting the parallel extraction routine.
# INFO: Extracting 7 points for chunk nr 2 at resolution 0.2
# INFO: Extracting 1 points for chunk nr 1 at resolution 0.2
# INFO: Extracting 1 points for chunk nr 0 at resolution 0.2
# INFO: 1 points for chunk nr 0 at resolution 0.2 extracted in:: 0:00:14.584318
# INFO: 1 points for chunk nr 1 at resolution 0.2 extracted in:: 0:00:17.123617
# INFO: 7 points for chunk nr 2 at resolution 0.2 extracted in:: 0:00:18.327501
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_034703
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_034703.
# WARNING: Not fully processed. Will retry at a higher aggregation level.
# INFO: Checking for points not processed at the current aggregation level.
# INFO: Found already processed files. Identifying already processed points and skipping them.
# INFO: Found 9 already processed points
# INFO: Points not yet processed are uploaded to Earth Engine.
# INFO: Create AOI from points and upload as temporary EE asset inside tmp_esbae_231108_035114.
# INFO: Creating processing chunks of 0.15 degrees for parallel extraction.
# INFO: Preparing the parallel extraction over a total of 10 chunks. This may take a while...
# INFO: Starting the parallel extraction routine.
# INFO: Extracting 63 points for chunk nr 6 at resolution 0.15
# INFO: Extracting 6 points for chunk nr 0 at resolution 0.15
# INFO: Extracting 85 points for chunk nr 3 at resolution 0.15
# INFO: Extracting 82 points for chunk nr 4 at resolution 0.15
# INFO: Extracting 99 points for chunk nr 7 at resolution 0.15
# INFO: Extracting 19 points for chunk nr 9 at resolution 0.15
# INFO: Extracting 80 points for chunk nr 2 at resolution 0.15
# INFO: Extracting 68 points for chunk nr 5 at resolution 0.15
# INFO: Extracting 55 points for chunk nr 1 at resolution 0.15
# INFO: Extracting 65 points for chunk nr 8 at resolution 0.15
# INFO: 19 points for chunk nr 9 at resolution 0.15 extracted in:: 0:00:35.530202
# INFO: 55 points for chunk nr 1 at resolution 0.15 extracted in:: 0:00:38.654726
# INFO: 85 points for chunk nr 3 at resolution 0.15 extracted in:: 0:00:45.051222
# INFO: 80 points for chunk nr 2 at resolution 0.15 extracted in:: 0:00:46.376683
# INFO: 99 points for chunk nr 7 at resolution 0.15 extracted in:: 0:00:51.015825
# INFO: 6 points for chunk nr 0 at resolution 0.15 extracted in:: 0:00:53.221203
# INFO: 65 points for chunk nr 8 at resolution 0.15 extracted in:: 0:00:56.588191
# INFO: 63 points for chunk nr 6 at resolution 0.15 extracted in:: 0:00:58.907163
# INFO: 68 points for chunk nr 5 at resolution 0.15 extracted in:: 0:01:05.957559
# INFO: 82 points for chunk nr 4 at resolution 0.15 extracted in:: 0:01:21.432888
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_035114
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_035114.
# WARNING: Not fully processed. Will retry at a higher aggregation level.
# INFO: Checking for points not processed at the current aggregation level.
# INFO: Found already processed files. Identifying already processed points and skipping them.
# INFO: Found 631 already processed points
# INFO: This batch of points has successfully been processed.
# ERROR: Extraction of time-series has failed or is incomplete with 222968 not being processed. You can check the logfile esbae_log_231107_191742 within your results directory.
# INFO: Cleaning up temporary Earth Engine assets created during the processing.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_192823
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_192823.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_193730
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_193730.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_195707
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_195707.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_200703
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_200703.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_201956
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_201956.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_204052
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_204052.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_205629
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_205629.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_210813
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_210813.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_211756
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_211756.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_213130
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_213130.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_214206
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_214206.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_220209
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_220209.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_221245
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_221245.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_222817
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_222817.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_223836
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_223836.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_224939
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_224939.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_230208
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_230208.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_230923
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_230923.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_232104
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_232104.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_233211
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_233211.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_234910
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231107_234910.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_000222
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_000222.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_001553
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_001553.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_003744
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_003744.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_005206
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_005206.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_010022
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_010022.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_012113
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_012113.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_012934
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_012934.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_013914
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_013914.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_015336
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_015336.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_020435
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_020435.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_021320
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_021320.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_023127
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_023127.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_024029
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_024029.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_025133
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_025133.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_030900
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_030900.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_031826
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_031826.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_032947
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_032947.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_034500
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_034500.
# INFO: Removing assets within asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_034857
# INFO: Removing asset folder projects/earthengine-legacy/assets/users/etchanak/tmp_esbae_231108_034857.
